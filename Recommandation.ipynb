# %%
import pandas as pd
import numpy as np
from sklearn.utils._estimator_html_repr import estimator_html_repr
import matplotlib.pyplot as plt

# %% [markdown]
# # Data

# %% [markdown]
# Les données extraites de la base de données Azure. `Executer le script extraction.py`. On suppose que les données ont été téléchargée dans le dossier `./data/`.

# %%
data_path = './data/data_ext_v4.tsv'

# %% [markdown]
# Chargement des données :

# %%
df = pd.read_csv(data_path, sep='\t', quoting=3)

# %%
df.head()
# Out:
#        tconst titleType    genre_1      genre_2   genre_3  \
# 0   tt2291966     movie  Biography  Documentary    Family
# 1   tt2378115     movie        NaN          NaN       NaN
# 2   tt2530242   tvMovie     Comedy          NaN       NaN
# 3  tt27505330     movie      Drama          NaN       NaN
# 4  tt22871554     movie      Drama      Mystery  Thriller
#
#                primaryTitle  isAdult  startYear  runtimeMinutes     actor_1  \
# 0               Farming 101    False       2012            80.0   nm5174409
# 1            Cecilia y Juan    False       2012             NaN   nm1570600
# 2      Das Millionen Rennen    False       2012            89.0   nm0695127
# 3                    Nevada    False       2023            89.0  nm14752449
# 4  A Haunting Winter's Tale    False       2022            65.0  nm13391370
#
#       actor_2     actor_3  director_1 director_2 director_3  averageRating  \
# 0         NaN         NaN   nm0709664        NaN        NaN            NaN
# 1   nm5021870         NaN   nm3913456        NaN        NaN            NaN
# 2   nm0517885   nm0499671   nm1054437        NaN        NaN            6.1
# 3   nm1235719  nm15159468   nm3807259  nm6281196        NaN            6.2
# 4  nm13392830  nm13392832  nm13390267        NaN        NaN            7.7
#
#    numVotes
# 0       NaN
# 1       NaN
# 2      68.0
# 3      10.0
# 4       6.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 669273 entries, 0 to 669272
# Data columns (total 17 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          669273 non-null  object
#  1   titleType       669273 non-null  object
#  2   genre_1         633878 non-null  object
#  3   genre_2         197851 non-null  object
#  4   genre_3         90136 non-null   object
#  5   primaryTitle    669271 non-null  object
#  6   isAdult         669273 non-null  bool
#  7   startYear       669273 non-null  int64
#  8   runtimeMinutes  407667 non-null  float64
#  9   actor_1         444242 non-null  object
#  10  actor_2         394240 non-null  object
#  11  actor_3         366097 non-null  object
#  12  director_1      392268 non-null  object
#  13  director_2      36476 non-null   object
#  14  director_3      5918 non-null    object
#  15  averageRating   320451 non-null  float64
#  16  numVotes        320451 non-null  float64
# dtypes: bool(1), float64(3), int64(1), object(12)
# memory usage: 82.3+ MB

# %%
df = df[df['averageRating'].notna()].reset_index()
df.shape
# Out:
# (320451, 18)

# %%
df.fillna({'genre_1' : 'None1', 'genre_2' : 'None2', 'genre_3': 'None3'}, inplace=True)

# %%
df['isAdult'] = df['isAdult'].astype(int)

# %%
from unidecode import unidecode
import re
from nltk.stem import PorterStemmer
def preprocess_title(title):
    """
    Preprocess movie/show titles for use in recommendation systems.
    
    Args:
        title: The primary title to preprocess. Can be string or float (np.nan)
        
    Returns:
        str: The preprocessed title
    """
    # Handle missing values
    if isinstance(title, float) and np.isnan(title):
        return "notitle"
    
    # Convert to string if not already
    title = str(title)
    
    # Convert to lowercase
    title = title.lower()
    
    # Normalize unicode characters
    title = unidecode(title)

    
    # Remove special characters and extra whitespace
    title = re.sub(r'[^\w\s]', ' ', title)  # Replace special chars with space
    title = re.sub(r'\s+', ' ', title)       # Replace multiple spaces with single space
    
    # Remove common words that don't add meaning
    stop_words = {'the', 's', 'a', 'an', 'and', 'or', 'but', 'in', 'on', 'at', 'to'}
    title_words = title.split()
    title_words = [word for word in title_words if word not in stop_words]
    
    # Remove year patterns (e.g., "(1999)" or "- 2020")
    title_words = [word for word in title_words if not re.match(r'^\d{4}$', word)]
    
    # Apply stemming
    stemmer = PorterStemmer()
    title_words = [stemmer.stem(word) for word in title_words]
    
    # Join words back together
    title = ' '.join(title_words)
    
    # Strip leading/trailing whitespace
    title = title.strip()
    
    return title

# %%
df["title"] = df['primaryTitle'].apply(preprocess_title)
df["logVotes"] = df['numVotes'].apply(np.log)

# %%
df.head()
# Out:
#    index      tconst titleType      genre_1  genre_2   genre_3  \
# 0      2   tt2530242   tvMovie       Comedy    None2     None3
# 1      3  tt27505330     movie        Drama    None2     None3
# 2      4  tt22871554     movie        Drama  Mystery  Thriller
# 3      5   tt6854792     movie        Drama  Romance     None3
# 4      6  tt10429264     movie  Documentary    None2     None3
#
#                    primaryTitle  isAdult  startYear  runtimeMinutes  \
# 0          Das Millionen Rennen        0       2012            89.0
# 1                        Nevada        0       2023            89.0
# 2      A Haunting Winter's Tale        0       2022            65.0
# 3  Sriramudinta Srikrishnudanta        0       2017           129.0
# 4                      Fabulous        0       2019            52.0
#
#       actor_1     actor_2     actor_3  director_1 director_2 director_3  \
# 0   nm0695127   nm0517885   nm0499671   nm1054437        NaN        NaN
# 1  nm14752449   nm1235719  nm15159468   nm3807259  nm6281196        NaN
# 2  nm13391370  nm13392830  nm13392832  nm13390267        NaN        NaN
# 3   nm8970446   nm8970447  nm10962932   nm8970443        NaN        NaN
# 4   nm8838626         NaN         NaN   nm5091578        NaN        NaN
#
#    averageRating  numVotes                         title  logVotes
# 0            6.1      68.0           da millionen rennen  4.219508
# 1            6.2      10.0                        nevada  2.302585
# 2            7.7       6.0             haunt winter tale  1.791759
# 3            7.1      44.0  sriramudinta srikrishnudanta  3.784190
# 4            6.5      16.0                         fabul  2.772589

# %% [markdown]
# # Système de Recommandation

# %% [markdown]
# Utilization d'un countvectorizer au lieu d'un MultiLabelBinarizer car Multilabel Binarizer n'est pas fait pour fonctionner dans une pipeline (*cf. [sckit-learn github issues 11309](https://github.com/scikit-learn/scikit-learn/issues/11309)*).

# %%
from sklearn.compose import ColumnTransformer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neighbors import NearestNeighbors

# %%
class RecSysCosine :

    def __init__(self, n=5, data_path='./data/vectorized_db3.npy'):
        self._n = n
        self.load_data(data_path)
    
    def load_data(self, data_path):
        self._X = np.load(data_path, allow_pickle=True)
        print(self._X.shape)
    
    def recommand(self, idx):
        Y = self._X[idx,:].reshape(1,-1)
        result = cosine_similarity(np.delete(self._X, idx, axis=0), Y).reshape(-1)
        
        idxs = np.argpartition(result, -self._n)[-self._n:]
        idxs = idxs[np.argsort(result[idxs])][::-1]

        return idxs

class RecSysKNN :

    def __init__(self, n=5, data_path='./data/vectorized_db3.npy'):
        self._n = n+1
        self.load_data(data_path)
    
    def load_data(self, data_path):
        self._X = np.load(data_path, allow_pickle=True)
        self.nbrs = NearestNeighbors(n_neighbors=self._n).fit(self._X)
        print(self._X.shape)
    
    def recommand(self, idx):
        _, idxs = self.nbrs.kneighbors(self._X[idx,:].reshape(1, -1))
    
        return idxs[0][1:]

# %%
numeric_features     = ["startYear", "averageRating", "logVotes"]
titletype_features = ['titleType']
genres_features = ['genre_1', 'genre_2', 'genre_3']
categorical_features = titletype_features + genres_features
text_features        = ["title" ,"actor_1", "actor_2", "actor_3", "director_1", "director_2", "director_3"]

# %%
numeric_transformer     = Pipeline(steps=[('imputer', SimpleImputer(strategy='constant', fill_value=0)), ('std', MinMaxScaler())])
categorical_transformer = Pipeline(steps=[('imputer', SimpleImputer(strategy='constant', fill_value='None')), ('vec', CountVectorizer(analyzer=list))])
textual_transformer     = Pipeline(steps=[('imputer', SimpleImputer(strategy='constant', fill_value='None')), ('vec', TfidfVectorizer(analyzer=list, min_df=2, max_features=10000)), ('svd', TruncatedSVD(n_components=200)), ('std', MinMaxScaler())])

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("numeric", numeric_transformer, numeric_features),
        ("categorical", ColumnTransformer(transformers=[
            ("titleT", categorical_transformer, titletype_features),
            ("genres", categorical_transformer, genres_features),
        ]), categorical_features),
        ("textual", textual_transformer, text_features)
    ]
)

# %%
preproc = Pipeline(steps=[('preprocessing', preprocessor)])
preproc
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('numeric',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=0,
#                                                                                  strategy='constant')),
#                                                                   ('std',
#                                                                    MinMaxScaler())]),
#                                                   ['startYear', 'averageRating',
#                                                    'logVotes']),
#                                                  ('categorical',
#                                                   ColumnTransformer(transformers=[('titleT',
#                                                                                    Pipeline(steps=[('imputer',
#                                                                                                     SimpleImputer(fill_value='None',
#                                                                                                                   strategy='const...
#                                                   ['titleType', 'genre_1',
#                                                    'genre_2', 'genre_3']),
#                                                  ('textual',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='None',
#                                                                                  strategy='constant')),
#                                                                   ('vec',
#                                                                    TfidfVectorizer(analyzer=<class 'list'>,
#                                                                                    max_features=10000,
#                                                                                    min_df=2)),
#                                                                   ('svd',
#                                                                    TruncatedSVD(n_components=200)),
#                                                                   ('std',
#                                                                    MinMaxScaler())]),
#                                                   ['title', 'actor_1',
#                                                    'actor_2', 'actor_3',
#                                                    'director_1', 'director_2',
#                                                    'director_3'])]))])

# %%
preproc_output = preproc.fit_transform(df)
filename = './data/vectorized_db4.npy'
np.save(filename, preproc_output)

# %% [markdown]
# # Tests

# %%
rec_cos = RecSysCosine(5, filename)
rec_knn = RecSysKNN(5, filename)
# Out:
# (320451, 237)
# (320451, 237)

# %%
cols = ['tconst', 'startYear', 'titleType','genre_1', 'genre_2', 'genre_3', 'primaryTitle', 'averageRating', 'numVotes']
wild_idx = df[df['primaryTitle'].fillna('').str.contains('The Wild Robot')].index.values[0]
harry_idx = df[df['primaryTitle'].fillna('').str.contains('Azkaban')].index.values[0]

# %% [markdown]
# ## The Wild Robot

# %%
idx = wild_idx
df.loc[idx, cols].reset_index().transpose()
# Out:
#                  0          1          2          3        4        5  \
# index       tconst  startYear  titleType    genre_1  genre_2  genre_3
# 233185  tt29623480       2024      movie  Animation   Sci-Fi    None3
#
#                      6              7         8
# index     primaryTitle  averageRating  numVotes
# 233185  The Wild Robot            8.2  118794.0

# %% [markdown]
# ### Cosine Similarity

# %%
df.loc[rec_cos.recommand(idx), cols]
# Out:
#             tconst  startYear titleType    genre_1 genre_2 genre_3  \
# 121013  tt28288396       2023     movie  Animation  Sci-Fi   None3
# 76199    tt5332274       2015     movie  Animation  Sci-Fi   None3
# 316904   tt1579541       2009     movie    Romance   None2   None3
# 151263  tt13726852       2020     movie  Animation  Sci-Fi   None3
# 223093  tt20562862       2021     movie  Animation  Sci-Fi   None3
#
#                                       primaryTitle  averageRating  numVotes
# 121013                                 The Missing            7.2     318.0
# 76199   Arpeggio of Blue Steel: Ars Nova - Cadenza            7.2     105.0
# 316904                          Evaraina Eppudaina            4.8      64.0
# 151263                                The Intruder            8.1      17.0
# 223093                          Bigfoot vs Krampus            2.9      81.0

# %% [markdown]
# ### KNN

# %%
df.loc[rec_knn.recommand(wild_idx), cols]
# Out:
#             tconst  startYear titleType    genre_1 genre_2 genre_3  \
# 121013  tt28288396       2023     movie  Animation  Sci-Fi   None3
# 76199    tt5332274       2015     movie  Animation  Sci-Fi   None3
# 316905   tt7504716       2017     movie  Animation  Sci-Fi   None3
# 151263  tt13726852       2020     movie  Animation  Sci-Fi   None3
# 223093  tt20562862       2021     movie  Animation  Sci-Fi   None3
#
#                                       primaryTitle  averageRating  numVotes
# 121013                                 The Missing            7.2     318.0
# 76199   Arpeggio of Blue Steel: Ars Nova - Cadenza            7.2     105.0
# 316905                     ChäoS;Child: Silent Sky            6.5      68.0
# 151263                                The Intruder            8.1      17.0
# 223093                          Bigfoot vs Krampus            2.9      81.0

# %% [markdown]
# ## Harry Potter

# %%
idx = harry_idx
df.loc[idx, cols].reset_index().transpose()
# Out:
#                0          1          2          3        4        5  \
# index     tconst  startYear  titleType    genre_1  genre_2  genre_3
# 91963  tt0304141       2004      movie  Adventure   Family  Fantasy
#
#                                               6              7         8
# index                              primaryTitle  averageRating  numVotes
# 91963  Harry Potter and the Prisoner of Azkaban            7.9  719001.0

# %% [markdown]
# ### Cosine Similarity

# %%
df.loc[rec_cos.recommand(idx), cols]
# Out:
#             tconst  startYear titleType    genre_1   genre_2  genre_3  \
# 177136   tt8634368       2018     movie     Comedy     Drama    None3
# 22143    tt0295297       2002     movie  Adventure    Family  Fantasy
# 240306  tt12058584       2021     movie      Drama  Thriller      War
# 31984    tt0926084       2010     movie  Adventure    Family  Fantasy
# 85464    tt1201607       2011     movie  Adventure    Family  Fantasy
#
#                                         primaryTitle  averageRating  numVotes
# 177136                                Jatt vs. Ielts            4.4     121.0
# 22143        Harry Potter and the Chamber of Secrets            7.4  719337.0
# 240306                                   Chess Story            6.8    5069.0
# 31984   Harry Potter and the Deathly Hallows: Part 1            7.7  622383.0
# 85464   Harry Potter and the Deathly Hallows: Part 2            8.1  982979.0

# %% [markdown]
# ### KNN

# %%
df.loc[rec_knn.recommand(idx), cols]
# Out:
#            tconst  startYear titleType    genre_1 genre_2  genre_3  \
# 177137  tt0330373       2005     movie  Adventure  Family  Fantasy
# 22143   tt0295297       2002     movie  Adventure  Family  Fantasy
# 240307  tt0241527       2001     movie  Adventure  Family  Fantasy
# 31984   tt0926084       2010     movie  Adventure  Family  Fantasy
# 85464   tt1201607       2011     movie  Adventure  Family  Fantasy
#
#                                         primaryTitle  averageRating  numVotes
# 177137           Harry Potter and the Goblet of Fire            7.7  707778.0
# 22143        Harry Potter and the Chamber of Secrets            7.4  719337.0
# 240307         Harry Potter and the Sorcerer's Stone            7.7  892057.0
# 31984   Harry Potter and the Deathly Hallows: Part 1            7.7  622383.0
# 85464   Harry Potter and the Deathly Hallows: Part 2            8.1  982979.0

# %%
preproc
# Out:
# Pipeline(steps=[('prec',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=0,
#                                                                                  strategy='constant')),
#                                                                   ('std',
#                                                                    MinMaxScaler())]),
#                                                   ['startYear', 'averageRating',
#                                                    'logVotes']),
#                                                  ('typ',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='None',
#                                                                                  strategy='constant')),
#                                                                   ('vec',
#                                                                    CountVectorizer(analyzer=<class 'list'>))]),
#                                                   ['titl...
#                                                                    CountVectorizer(analyzer=<class 'list'>))]),
#                                                   ['genre_1', 'genre_2',
#                                                    'genre_3']),
#                                                  ('txt',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='None',
#                                                                                  strategy='constant')),
#                                                                   ('vec',
#                                                                    TfidfVectorizer(analyzer=<class 'list'>,
#                                                                                    max_features=10000,
#                                                                                    min_df=2)),
#                                                                   ('svd',
#                                                                    TruncatedSVD(n_components=200)),
#                                                                   ('std',
#                                                                    MinMaxScaler())]),
#                                                   ['title', 'actor_1',
#                                                    'actor_2', 'actor_3',
#                                                    'director_1', 'director_2',
#                                                    'director_3'])]))])

# %%
import joblib

# %%
joblib.dump(preproc, 'filename.pkl', compress = 1)
# Out:
# ['filename.pkl']

# %%
joblib.load('filename.pkl')
# Out:
# Pipeline(steps=[('prec',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=0,
#                                                                                  strategy='constant')),
#                                                                   ('std',
#                                                                    MinMaxScaler())]),
#                                                   ['startYear', 'averageRating',
#                                                    'logVotes']),
#                                                  ('typ',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='None',
#                                                                                  strategy='constant')),
#                                                                   ('vec',
#                                                                    CountVectorizer(analyzer=<class 'list'>))]),
#                                                   ['titl...
#                                                                    CountVectorizer(analyzer=<class 'list'>))]),
#                                                   ['genre_1', 'genre_2',
#                                                    'genre_3']),
#                                                  ('txt',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='None',
#                                                                                  strategy='constant')),
#                                                                   ('vec',
#                                                                    TfidfVectorizer(analyzer=<class 'list'>,
#                                                                                    max_features=10000,
#                                                                                    min_df=2)),
#                                                                   ('svd',
#                                                                    TruncatedSVD(n_components=200)),
#                                                                   ('std',
#                                                                    MinMaxScaler())]),
#                                                   ['title', 'actor_1',
#                                                    'actor_2', 'actor_3',
#                                                    'director_1', 'director_2',
#                                                    'director_3'])]))])

# %%
df_x = df.sample(100000).reset_index()

# %%
preproc_output = preproc.fit_transform(df_x)
filename = './data/vectorized_db5.npy'
np.save(filename, preproc_output)

# %%
rec_cos = RecSysCosine(5, filename)
rec_knn = RecSysKNN(5, filename)
# Out:
# (100000, 237)
# (100000, 237)

# %%
harry_idx = df_x[df_x['primaryTitle'].fillna('').str.contains('Azkaban')].index.values[0]
idx = harry_idx
df_x.loc[idx, cols].reset_index().transpose()
# Out:
#                0          1          2          3        4        5  \
# index     tconst  startYear  titleType    genre_1  genre_2  genre_3
# 33268  tt0304141       2004      movie  Adventure   Family  Fantasy
#
#                                               6              7         8
# index                              primaryTitle  averageRating  numVotes
# 33268  Harry Potter and the Prisoner of Azkaban            7.9  719001.0

# %%
df_x.loc[rec_knn.recommand(idx), cols]
# Out:
#           tconst  startYear titleType    genre_1 genre_2  genre_3  \
# 28852  tt0330373       2005     movie  Adventure  Family  Fantasy
# 64102  tt0316396       2003     movie  Adventure  Family  Fantasy
# 14433  tt0396707       2008     movie  Adventure  Family  Fantasy
# 42940  tt0467923       2005     movie  Adventure  Family  Fantasy
# 95453  tt3183660       2016     movie  Adventure  Family  Fantasy
#
#                                   primaryTitle  averageRating  numVotes
# 28852      Harry Potter and the Goblet of Fire            7.7  707778.0
# 64102                                Peter Pan            6.8   81958.0
# 14433                   The Secret of Moonacre            6.0   11315.0
# 42940                         Gamera the Brave            6.6    1538.0
# 95453  Fantastic Beasts and Where to Find Them            7.2  520441.0

# %%
rec_knn.recommand(idx)
# Out:
# array([22049, 13701,  4531, 35145,  8806])

# %%
#wild_idx = df_x[df_x['primaryTitle'].fillna('').str.contains('The Wild Robot')].index.values[0]
idx = harry_idx
print(idx)
df_x.loc[idx, cols].reset_index().transpose()
# Out:
# 33268
#                0          1          2          3        4        5  \
# index     tconst  startYear  titleType    genre_1  genre_2  genre_3
# 33268  tt0304141       2004      movie  Adventure   Family  Fantasy
#
#                                               6              7         8
# index                              primaryTitle  averageRating  numVotes
# 33268  Harry Potter and the Prisoner of Azkaban            7.9  719001.0

# %%
df_x.to_csv("./save_data_clean.tsv", sep="\t")

# %%
df_x
# Out:
#        level_0   index      tconst titleType      genre_1  genre_2  \
# 0       162327  338304  tt14188286     movie        Drama    None2
# 1       166678  347457  tt14928598     movie  Documentary    None2
# 2       106935  222848   tt1890296  tvSeries        Drama  Romance
# 3       208048  433511  tt15417012     movie        Drama    None2
# 4        47823   98895   tt8396352     movie        Drama    None2
# ...        ...     ...         ...       ...          ...      ...
# 99995    75991  158535   tt1532348     movie        Drama  Romance
# 99996   304980  636269  tt23313124  tvSeries  Documentary  Mystery
# 99997   203895  424547   tt0381700     movie        Drama    None2
# 99998   124252  258123  tt35044216     movie  Documentary    None2
# 99999    25517   53116  tt30068793     movie  Documentary    None2
#
#           genre_3                                       primaryTitle  isAdult  \
# 0           None3                                  Preethse Preethse        0
# 1           None3              Delhi Riots... A tale of burn & blame        0
# 2           None3                    Unfaithful: Stories of Betrayal        0
# 3           None3                                   Hondisi Bareyiri        0
# 4           None3                                           Wagherya        0
# ...           ...                                                ...      ...
# 99995       None3                                            Juliets        0
# 99996  Reality-TV                                      Spøkelsesjakt        0
# 99997       None3                                             Warsaw        0
# 99998       None3   Purrkur Pillnikk: Sofandi vakandi lifandi dauður        0
# 99999       None3  Mossuk kezeinket - az eltitkolt kórházi fertõz...        0
#
#        startYear  ...     actor_1     actor_2     actor_3  director_1  \
# 0           2009  ...   nm1693209   nm2794672   nm2994788   nm7843279
# 1           2020  ...  nm15387694  nm14987512  nm15385736  nm15391045
# 2           2011  ...   nm5183339   nm4433629   nm4433629         NaN
# 3           2023  ...   nm4942567  nm11739510  nm14753357  nm10130310
# 4           2018  ...   nm1063477   nm3874318   nm2778815   nm7669214
# ...          ...  ...         ...         ...         ...         ...
# 99995       2010  ...   nm0398852   nm2119124   nm3120588   nm0155446
# 99996       2022  ...         NaN         NaN         NaN         NaN
# 99997       2003  ...   nm1377449   nm0307591   nm0652278   nm1375125
# 99998       2024  ...         NaN         NaN         NaN  nm16833687
# 99999       2023  ...  nm15502646  nm15502647         NaN   nm8829402
#
#       director_2 director_3 averageRating  numVotes  \
# 0            NaN        NaN           5.4       5.0
# 1      nm5550111  nm9633525           8.9      42.0
# 2            NaN        NaN           8.6      38.0
# 3            NaN        NaN           7.8     687.0
# 4            NaN        NaN           7.7      25.0
# ...          ...        ...           ...       ...
# 99995  nm2254001  nm0791479           6.0     184.0
# 99996        NaN        NaN           7.8      13.0
# 99997        NaN        NaN           6.1     473.0
# 99998        NaN        NaN           9.2       5.0
# 99999  nm9589182        NaN           8.0       5.0
#
#                                                    title  logVotes
# 0                                        preeths preeths  1.609438
# 1                          delhi riot tale of burn blame  3.737670
# 2                                unfaith stori of betray  3.637586
# 3                                       hondisi bareyiri  6.532334
# 4                                               wagherya  3.218876
# ...                                                  ...       ...
# 99995                                             juliet  5.214936
# 99996                                      spokelsesjakt  2.564949
# 99997                                             warsaw  6.159095
# 99998    purrkur pillnikk sofandi vakandi lifandi daudur  1.609438
# 99999  mossuk kezeinket az eltitkolt korhazi fertozes...  1.609438
#
# [100000 rows x 21 columns]

# %%
df_x.shape
# Out:
# (100000, 21)

# %%
df_y = pd.read_csv("./save_data_clean.tsv", sep="\t")

# %%
df_y.head()
# Out:
#    Unnamed: 0  level_0   index      tconst titleType      genre_1  genre_2  \
# 0           0   162327  338304  tt14188286     movie        Drama    None2
# 1           1   166678  347457  tt14928598     movie  Documentary    None2
# 2           2   106935  222848   tt1890296  tvSeries        Drama  Romance
# 3           3   208048  433511  tt15417012     movie        Drama    None2
# 4           4    47823   98895   tt8396352     movie        Drama    None2
#
#   genre_3                           primaryTitle  isAdult  ...     actor_1  \
# 0   None3                      Preethse Preethse        0  ...   nm1693209
# 1   None3  Delhi Riots... A tale of burn & blame        0  ...  nm15387694
# 2   None3        Unfaithful: Stories of Betrayal        0  ...   nm5183339
# 3   None3                       Hondisi Bareyiri        0  ...   nm4942567
# 4   None3                               Wagherya        0  ...   nm1063477
#
#       actor_2     actor_3  director_1 director_2 director_3 averageRating  \
# 0   nm2794672   nm2994788   nm7843279        NaN        NaN           5.4
# 1  nm14987512  nm15385736  nm15391045  nm5550111  nm9633525           8.9
# 2   nm4433629   nm4433629         NaN        NaN        NaN           8.6
# 3  nm11739510  nm14753357  nm10130310        NaN        NaN           7.8
# 4   nm3874318   nm2778815   nm7669214        NaN        NaN           7.7
#
#   numVotes                          title  logVotes
# 0      5.0                preeths preeths  1.609438
# 1     42.0  delhi riot tale of burn blame  3.737670
# 2     38.0        unfaith stori of betray  3.637586
# 3    687.0               hondisi bareyiri  6.532334
# 4     25.0                       wagherya  3.218876
#
# [5 rows x 22 columns]

# %%
import joblib
pipe = joblib.load('./model/recsys.pkl')

# %%
pipe
# Out:
# Pipeline(steps=[('prec',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=0,
#                                                                                  strategy='constant')),
#                                                                   ('std',
#                                                                    MinMaxScaler())]),
#                                                   ['startYear', 'averageRating',
#                                                    'logVotes']),
#                                                  ('typ',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='None',
#                                                                                  strategy='constant')),
#                                                                   ('vec',
#                                                                    CountVectorizer(analyzer=<class 'list'>))]),
#                                                   ['titl...
#                                                                    CountVectorizer(analyzer=<class 'list'>))]),
#                                                   ['genre_1', 'genre_2',
#                                                    'genre_3']),
#                                                  ('txt',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='None',
#                                                                                  strategy='constant')),
#                                                                   ('vec',
#                                                                    TfidfVectorizer(analyzer=<class 'list'>,
#                                                                                    max_features=10000,
#                                                                                    min_df=2)),
#                                                                   ('svd',
#                                                                    TruncatedSVD(n_components=200)),
#                                                                   ('std',
#                                                                    MinMaxScaler())]),
#                                                   ['title', 'actor_1',
#                                                    'actor_2', 'actor_3',
#                                                    'director_1', 'director_2',
#                                                    'director_3'])]))])

# %%
pipe.fit(df_y)
# Out:
# Pipeline(steps=[('prec',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=0,
#                                                                                  strategy='constant')),
#                                                                   ('std',
#                                                                    MinMaxScaler())]),
#                                                   ['startYear', 'averageRating',
#                                                    'logVotes']),
#                                                  ('typ',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='None',
#                                                                                  strategy='constant')),
#                                                                   ('vec',
#                                                                    CountVectorizer(analyzer=<class 'list'>))]),
#                                                   ['titl...
#                                                                    CountVectorizer(analyzer=<class 'list'>))]),
#                                                   ['genre_1', 'genre_2',
#                                                    'genre_3']),
#                                                  ('txt',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='None',
#                                                                                  strategy='constant')),
#                                                                   ('vec',
#                                                                    TfidfVectorizer(analyzer=<class 'list'>,
#                                                                                    max_features=10000,
#                                                                                    min_df=2)),
#                                                                   ('svd',
#                                                                    TruncatedSVD(n_components=200)),
#                                                                   ('std',
#                                                                    MinMaxScaler())]),
#                                                   ['title', 'actor_1',
#                                                    'actor_2', 'actor_3',
#                                                    'director_1', 'director_2',
#                                                    'director_3'])]))])

# %%
df_y[['actor_1', 'actor_2', 'actor_3', 'director_1', 'director_2', 'director_3']].fillna('')
# Out:
#           actor_1     actor_2     actor_3  director_1 director_2 director_3
# 0       nm1693209   nm2794672   nm2994788   nm7843279
# 1      nm15387694  nm14987512  nm15385736  nm15391045  nm5550111  nm9633525
# 2       nm5183339   nm4433629   nm4433629
# 3       nm4942567  nm11739510  nm14753357  nm10130310
# 4       nm1063477   nm3874318   nm2778815   nm7669214
# ...           ...         ...         ...         ...        ...        ...
# 99995   nm0398852   nm2119124   nm3120588   nm0155446  nm2254001  nm0791479
# 99996
# 99997   nm1377449   nm0307591   nm0652278   nm1375125
# 99998                                      nm16833687
# 99999  nm15502646  nm15502647               nm8829402  nm9589182
#
# [100000 rows x 6 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df_y[['actor_1', 'actor_2', 'actor_3', 'director_1', 'director_2', 'director_3']].fillna('').explode()
#
# TypeError: DataFrame.explode() missing 1 required positional argument: 'column'

# %%
for i in df_y[['actor_1', 'actor_2', 'actor_3', 'director_1', 'director_2', 'director_3']].fillna('').iterrows():
    for j in i[1]: print(type(j))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
