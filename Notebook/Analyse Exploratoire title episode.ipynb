# %%
import pandas as pd
import numpy as np
from collections import Counter
import plotly.express as px
import missingno as msno
import seaborn as sns
import matplotlib.pyplot as plt

# %%
datafolder = '../data/data-10k/'

# %%
titleepisode= 'title.episode-10k.tsv'

# %%
df= pd.read_csv(datafolder + titleepisode, sep='\t', quoting = 3)

# %%
df.head()
# Out:
#       tconst parentTconst seasonNumber episodeNumber
# 0  tt0031458   tt32857063           \N            \N
# 1  tt0041951    tt0041038            1             9
# 2  tt0042816    tt0989125            1            17
# 3  tt0042889    tt0989125           \N            \N
# 4  tt0043426    tt0040051            3            42

# %%
df_null = df.replace(r"\N", None )

# %%
msno.matrix(df_null)
# Out:
# <Axes: >

# %%
df["tconst"].nunique()
# Out:
# 9999

# %%
df["parentTconst"].nunique()
# Out:
# 1569
