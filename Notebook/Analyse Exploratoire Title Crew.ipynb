# %% [markdown]
# # Import des bibliothèques

# %%
import pandas as pd
import numpy as np
from collections import Counter
import plotly.express as px
import missingno as msno
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Lecture du fichier

# %%
datafolder = '../data/data-10k/'

# %%
titlecrew= 'title.crew-10k.tsv'

# %%
df= pd.read_csv(datafolder + titlecrew, sep='\t', quoting = 3)

# %%
df.head()
# Out:
#       tconst  directors writers
# 0  tt0000001  nm0005690      \N
# 1  tt0000002  nm0721526      \N
# 2  tt0000003  nm0721526      \N
# 3  tt0000004  nm0721526      \N
# 4  tt0000005  nm0005690      \N

# %% [markdown]
# # Observation des valeurs nulles dans le dataset

# %%
df_null = df.replace(r"\N", None )

# %%
msno.matrix(df_null)
# Out:
# <Axes: >

# %% [markdown]
# # Unicité des valeurs

# %%
df["tconst"].nunique()
# Out:
# 9999

# %%
df["directors"].nunique()
# Out:
# 1401

# %%
df["writers"].nunique()
# Out:
# 3785

# %% [markdown]
# # Création de liste contenant les directeurs et les écrivains

# %%
df["liste_directors"] = df['directors'].str.split(',')
df["liste_writers"] = df['directors'].str.split(',')
df.head()
# Out:
#       tconst  directors writers liste_directors liste_writers
# 0  tt0000001  nm0005690      \N     [nm0005690]   [nm0005690]
# 1  tt0000002  nm0721526      \N     [nm0721526]   [nm0721526]
# 2  tt0000003  nm0721526      \N     [nm0721526]   [nm0721526]
# 3  tt0000004  nm0721526      \N     [nm0721526]   [nm0721526]
# 4  tt0000005  nm0005690      \N     [nm0005690]   [nm0005690]

# %%
count_liste_directors = df["liste_directors"].explode().tolist()
count_liste_writers = df["liste_writers"].explode().tolist()

# %%
compte_directors = Counter(count_liste_directors)
compte_directors
# Out:
# Counter({'\\N': 734,
#          'nm0000428': 487,
#          'nm0001908': 210,
#          'nm0294276': 195,
#          'nm0349785': 193,
#          'nm0784407': 163,
#          'nm0806565': 146,
#          'nm0617588': 113,
#          'nm0279404': 112,
#          'nm0594291': 108,
#          'nm0005717': 103,
#          'nm0245385': 82,
#          'nm0205986': 80,
#          'nm0730018': 77,
#          'nm0577654': 75,
#          'nm0408436': 75,
#          'nm0111753': 74,
#          'nm0132324': 70,
#          'nm0000779': 70,
#          'nm0208657': 63,
#          'nm0692105': 62,
#          'nm0408433': 62,
#          'nm0127511': 56,
#          'nm0002177': 55,
#          'nm0237713': 53,
#          'nm0085865': 52,
#          'nm0119138': 52,
#          'nm0717468': 52,
#          'nm0403319': 51,
#          'nm0515979': 49,
#          'nm0877783': 48,
#          'nm0288616': 48,
#          'nm0000122': 48,
#          'nm0169871': 46,
#          'nm0488932': 45,
# ...

# %%
compte_writers = Counter(count_liste_writers)
compte_writers
# Out:
# Counter({'\\N': 734,
#          'nm0000428': 487,
#          'nm0001908': 210,
#          'nm0294276': 195,
#          'nm0349785': 193,
#          'nm0784407': 163,
#          'nm0806565': 146,
#          'nm0617588': 113,
#          'nm0279404': 112,
#          'nm0594291': 108,
#          'nm0005717': 103,
#          'nm0245385': 82,
#          'nm0205986': 80,
#          'nm0730018': 77,
#          'nm0577654': 75,
#          'nm0408436': 75,
#          'nm0111753': 74,
#          'nm0132324': 70,
#          'nm0000779': 70,
#          'nm0208657': 63,
#          'nm0692105': 62,
#          'nm0408433': 62,
#          'nm0127511': 56,
#          'nm0002177': 55,
#          'nm0237713': 53,
#          'nm0085865': 52,
#          'nm0119138': 52,
#          'nm0717468': 52,
#          'nm0403319': 51,
#          'nm0515979': 49,
#          'nm0877783': 48,
#          'nm0288616': 48,
#          'nm0000122': 48,
#          'nm0169871': 46,
#          'nm0488932': 45,
# ...
